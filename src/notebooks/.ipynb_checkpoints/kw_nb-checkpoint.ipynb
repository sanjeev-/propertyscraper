# %%
import os
import sys
from bs4 import BeautifulSoup
from requests import get

# %%
char_url = 'http://www.mlsfinder.com/ncsc_cmls/kw_975/index.cfm?action=searchresults&searchkey=10226637-b53a-fd37-d60c-1f1b2dbb6189&domain=concordkannapolis.kwoffice.net&nSite=Y&so=mc&sr=1'

# %%
charlotte_soup = BeautifulSoup(get(char_url).text,'lxml')

# %%
charlotte_soup
# Out:
# <!DOCTYPE html>\n\n<html xmlns="http://www.w3.org/1999/xhtml"><!--this tag is closed in footer.jsp--><head><meta content="text/html; charset=unicode-escape" http-equiv="Content-Type"/><script type="text/javascript">var NREUMQ=NREUMQ||[];NREUMQ.push(["mark","firstbyte",new Date().getTime()]);</script><link href="http://images.kw.com/kwintranet/static/css/global/kwDefault.css" rel="stylesheet" type="text/css"/><link href="http://images.kw.com/kw/static/css/global-kwNav.css" rel="stylesheet" type="text/css"/><link href="http://images.kw.com/kw/static/css/kw2-base.css" rel="stylesheet" type="text/css"/><link href="http://images.kw.com/kw/static/css/kw2-footerLayout-threeCol_home.css" rel="stylesheet" type="text/css"/><link href="http://images.kw.com/kw/static/css/kw-overrides.css" rel="stylesheet" type="text/css"/><title>Keller Williams Real Estate, Concord-Kannapolis</title><meta content="Search real estate in Concord, Kannapolis and Charlotte. Access listings including photos, maps, an
# ...

# %%
import selenium
import selenium.webdriver as webdriver
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
path_to_binary = "C:\Program Files (x86)\\Mozilla Firefox\\firefox.exe"
binary = FirefoxBinary(path_to_binary)
driver = webdriver.Firefox(firefox_binary=binary)

# %%
charlotte_soup.find_all('div',class_='wntGenericListingAddress')
# Out:
# []

# %%
driver.get(char_url)
selenium_soup = BeautifulSoup(driver.page_source)
# Out:
# C:\Users\Sanjeev\Anaconda2\lib\site-packages\bs4\__init__.py:166: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# To get rid of this warning, change this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
selenium_soup
# Out:
# <!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml"><!--this tag is closed in footer.jsp--><head><meta content="text/html; charset=unicode-escape" http-equiv="Content-Type"/><script id="hs-analytics" src="//js.hs-analytics.net/analytics/1516396200000/533235.js"></script><script async="" src="http://www.google-analytics.com/ga.js" type="text/javascript"></script><script type="text/javascript">var NREUMQ=NREUMQ||[];NREUMQ.push(["mark","firstbyte",new Date().getTime()]);</script><link href="http://images.kw.com/kwintranet/static/css/global/kwDefault.css" rel="stylesheet" type="text/css"/><link href="http://images.kw.com/kw/static/css/global-kwNav.css" rel="stylesheet" type="text/css"/><link href="http://images.kw.com/kw/static/css/kw2-base.css" rel="stylesheet" type="text/css"/><link href="http://images.kw.com/kw/static/css/kw2-footerLayout-threeCol_home.css" rel="stylesheet" type="text/css"/><link href="http://images.kw.com/kw/static/css/kw-overrides.css" rel="stylesheet" type=
# ...
